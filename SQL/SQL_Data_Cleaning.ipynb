# %%
"""
Step 1: Remove Duplicates
SELECT DISTINCT * FROOM <Table>
"""

# %%
"""
Step 2: TRIM white spaces
SELECT TRIM(<ColumnName>) FROM <Table>
"""

# %%
"""
Step3: Remove invalid Values

SELECT * FROM <Table> WHERE <ColumnName> IS NOT NULL AND <ColumnName> <> ''
"""

# %%
"""
Step4: Standardize Formats
SELECT FORMAT(<DateColumnName>, ""yyyy-MM-dd") AS <CLEAN_DATE> FROM <Table>
"""

# %%
"""
Step5: Handle Null Values
SELECT COALESCE(<ColumnName>, <"DefaultValue">) AS <ColumnName> FROM <Table>

"""

# %%
"""
Step6: Handling Inconsistent Cases
SELECT LOWER(<ColumnName>) AS <LoweCase_ColumnName> FROM <Table>
"""

# %%
"""
Step7: Correct Data Types
SELECT CAST(<ColumnName> AS <DataType>) AS <ColumnName> FROM <Table>
SELECT CAST(AGE AS INT) AS AGE FROM Employees
"""

# %%
    """
    Remove Invalid Characters
    UPDATE <Table> SET <ColumnName> = REPLACE(<ColumnName>, <InvalidCharacter>,'')
    UPDATE Employees SET Address = REPLACE(Address,'#','')
    """
