# %%
# %sql
/* Display unique match between teams using self join:

AFG Vs AUS
AFG Vs PAK
AFG Vs IND
IND Vs PAK
AUS Vs PAK
AUS Vs IND
*/

select concat(t1.teams, ' Vs ', t2.teams) from teams as t1 join teams as t2
on t1.teams < t2.teams

# %%
# %sql
show tables

# %%
# %sql
create table teams (teams varchar(20))

# %%
# %sql
insert into table teams values ("IND"), ("AUS"), ("PAK"), ("AFG")

# %%
# %sql
select * from teams

# %%
# %sql

select concat(t1.teams, ' Vs ', t2.teams) from teams as t1 join teams as t2
on t1.teams < t2.teams

# %%
# %sql
CREATE TABLE sales (
  id BIGINT GENERATED ALWAYS AS IDENTITY PRIMARY KEY,
  emp STRING,
  dept STRING,
  sale_date DATE,
  amount INT
);

INSERT INTO sales (emp, dept, sale_date, amount) VALUES
('Alice','A','2025-01-01',100),
('Alice','A','2025-01-02',150),
('Alice','A','2025-01-03',200),
('Bob','A','2025-01-01',120),
('Bob','A','2025-01-03',180),
('Cara','B','2025-01-01',90),
('Cara','B','2025-01-02',110);

# %%
# %sql
select distinct(emp, dept) from sales
